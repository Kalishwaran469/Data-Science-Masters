# %%
# question 1

# %%
# Clustering analysis is broadly used in many applications such as market research, pattern recognition, data analysis, and image processing. Clustering can also help marketers discover distinct groups in their customer base. And they can characterize their customer groups based on the purchasing patterns.

# %%
# question 2

# %%
# dbscan clustering is a technique used to find core point,border point,outliers.for finding all of the points first we need to predefined a two parameters like min_samples and epsilon.min_samples means minimum points need to be appeared in a particular cluster on the otherhand epsilon means radius using these two terms only dbscan working effectively.The advantage of the DBSCAN algorithm over the K-Means algorithm, is that the DBSCAN can determine which data points are noise or outliers.

# %%
# question 3

# %%
# The eps should be chosen based on the distance of the dataset (we can use a k-distance graph to find it), but in general small eps values are preferable. minPoints: As a general rule, a minimum minPoints can be derived from a number of dimensions (D) in the data set, as minPoints ≥ D + 1.

# %%
# question 4

# %%
# DBSCAN is a powerful clustering algorithm that can be used for outlier detection in machine learning. It works by finding clusters of points based on their density and labeling points that do not belong to any cluster as outliers.

# %%
# question 5

# %%
# K-means needs a prototype-based concept of a cluster. DBSCAN needs a density-based concept. K-means has difficulty with non-globular clusters and clusters of multiple sizes. DBSCAN is used to handle clusters of multiple sizes and structures and is not powerfully influenced by noise or outliers.

# %%
# question 6

# %%
# DBSCAN is a typically used clustering algorithm due to its clustering ability for arbitrarily-shaped clusters and its robustness to outliers. Generally, the complexity of DBSCAN is O(n^2) in the worst case, and it practically becomes more severe in higher dimension.

# %%
# question 7

# %%
# DBSCAN can find clusters of arbitrary shapes, but it cannot handle data containing clusters of varying densities. Further, the cluster quality in DBSCAN algorithm depends on the ability of the user to select a good set of parameters.

# %%
# question 8

# %%
#  Silhouette Coefficient is a best evaluation metric used to assess the quality of the clustering results. The Silhouette Coefficient is bounded between 1 and -1. The best value is 1, the worst is -1. A higher score indicates that the model has better defined, more dense clusters.

# %%
# question 9

# %%
# DBSCAN and other 'unsupervised' clustering methods can be used to automatically propagate labels used by classifiers (a 'supervised' machine learning task) in what as known as 'semi-supervised' machine learning.

# %%
# question 10

# %%
# DBSCAN stands for density-based spatial clustering of applications with noise. It is able to find arbitrary shaped clusters and clusters with noise (i.e. outliers).

# %%
# question 11

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons

# %%
X,y=make_moons(n_samples=100,noise=0)

# %%
plt.scatter(X[:,0],X[:,1],c=y)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_scaled=scaler.fit_transform(X)

# %%
dbscan=DBSCAN(eps=0.5)

# %%
dbscan.fit(X_scaled)
# Out:
# DBSCAN()

# %%
plt.scatter(X_scaled[:,0],X_scaled[:,1],c=dbscan.labels_)
