# %%
# question 1

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_excel('flight_price.xlsx')

# %%
df.shape
# Out:
# (10683, 11)

# %%
# question 2

# %%
sns.histplot(df['Price'],kde=True,bins=30)
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Count'>

# %%
# question 3

# %%
df['Price'].describe()
# Out:
# count    10683.000000
# mean      9087.064121
# std       4611.359167
# min       1759.000000
# 25%       5277.000000
# 50%       8372.000000
# 75%      12373.000000
# max      79512.000000
# Name: Price, dtype: float64

# %%
# minimum price is 1759 and maximum price is 79512

# %%
# question 4

# %%
df['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
sns.boxplot(x=df['Price'],y=df['Airline'],data=df,)
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Airline'>

# %%
# question 5

# %%
sns.boxplot(data=df)
# Out:
# <AxesSubplot: >

# %%
# in price feature there are so many outliers are there it's definetly affects the dataset

# %%
# question 9

# %%
df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')

# %%
df_copy=df.copy()
df.shape
# Out:
# (10841, 13)

# %%
# dataset have 10841 rows and 13 columns

# %%
# question 10

# %%
df_copy['Rating'].isnull().sum()
# Out:
# 1474

# %%
df_copy['rating']=df_copy['Rating'].dropna()

# %%
df_copy['Rating'].value_counts().sum()
# Out:
# 9367

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
sns.boxplot(x='Rating',y='Category',data=df_copy)
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='Category'>

# %%
# question 11

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
# question 12

# %%
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '5.5M', '17M', '39M', '31M',
#        '4.2M', '23M', '6.0M', '6.1M', '4.6M', '9.2M', '5.2M', '11M',
#        '24M', 'Varies with device', '9.4M', '15M', '10M', '1.2M', '26M',
#        '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k', '3.6M', '5.7M',
#        '8.6M', '2.4M', '27M', '2.7M', '2.5M', '7.0M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '22M', '6.4M', '3.2M', '8.2M', '4.9M', '9.5M', '5.0M',
#        '5.9M', '13M', '73M', '6.8M', '3.5M', '4.0M', '2.3M', '2.1M',
#        '42M', '9.1M', '55M', '23k', '7.3M', '6.5M', '1.5M', '7.5M', '51M',
#        '41M', '48M', '8.5M', '46M', '8.3M', '4.3M', '4.7M', '3.3M', '40M',
#        '7.8M', '8.8M', '6.6M', '5.1M', '61M', '66M', '79k', '8.4M',
# ...

# %%
df['Size']=df['Size'].str.replace('M','000')
df['Size']=df['Size'].str.replace('k','')
df['Size']=df['Size'].replace('Varies with device',np.nan)
df['Size']=df['Size'].astype(float)

# %%
sns.scatterplot(x=df['Size'],y=df['Rating'])
# Out:
# <AxesSubplot: xlabel='Size', ylabel='Rating'>

# %%
df['month']=df['Last Updated'].str.split(',').str[0].str.split(' ').str[0]
df['d']=df['Last Updated'].str.split(',').str[0].str.split(' ').str[0]
df['month']=df['Last Updated'].str.split(',').str[0].str.split(' ').str[0]

# %%
df['month']
# Out:
# 0        January
# 1        January
# 2         August
# 3           June
# 4           June
#           ...
# 10836       July
# 10837       July
# 10838    January
# 10839    January
# 10840       July
# Name: month, Length: 10841, dtype: object
